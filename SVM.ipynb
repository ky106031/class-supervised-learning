# %% [markdown]
# # サポートベクトルマシン

# %%
from sklearn.svm import SVC  # サポートベクトルマシン：クラス識別用（Support Vector Classifier）
from sklearn.datasets import fetch_openml  # データセットのダウンロード取得用
import pandas as pd  # データフレーム操作用
import matplotlib.pyplot as plt  # グラフ描画用

# %%
# 1. データセットの取得
dataset = fetch_openml("pima-indians-diabetes", version=1, as_frame=True)  # Pimaデータセットを取得
# こんな感じのデータです．8変数の説明変数．Outcomeは0 or 1
dataset.frame.head()  # データフレームの最初の5行を表示
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0      1.0
# 1                     0.351  31.0      0.0
# 2                     0.672  32.0      1.0
# 3                     0.167  21.0      0.0
# 4                     2.288  33.0      1.0

# %%
# 1.1 参考までに相関行列を表示
corr = dataset.frame.corr()
# 相関行列をヒートマップで表示．有効数字2桁
corr.style.format(precision=2).background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_6adab_row0_col0, #T_6adab_row1_col1, #T_6adab_row2_col2, #T_6adab_row3_col3, #T_6adab_row4_col4, #T_6adab_row5_col5, #T_6adab_row6_col6, #T_6adab_row7_col7, #T_6adab_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6adab_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_6adab_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_6adab_row0_col3, #T_6adab_row7_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_6adab_row0_col4, #T_6adab_row0_col5, #T_6adab_row0_col6, #T_6adab_row2_col8, #T_6adab_row3_col0, #T_6adab_row3_col1, #T_6adab_row3_col7, #T_6adab_row6_col2, #T_6adab_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6adab_row0_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_6adab_row0_col8, #T_6adab_row1_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_6adab_row1_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_6adab_row1_col2, #T_6adab_row6_col8 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_6adab_row1_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_6adab_row1_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_6adab_row1_col5, #T_6adab_row3_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_6adab_row1_col7 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_6adab_row1_col8 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_6adab_row2_col0, #T_6adab_row7_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_6adab_row2_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_6adab_row2_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_6adab_row2_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_6adab_row2_col5, #T_6adab_row6_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_6adab_row2_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_6adab_row2_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_6adab_row3_col2, #T_6adab_row5_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_6adab_row3_col4 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_6adab_row3_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_6adab_row3_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_6adab_row4_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_6adab_row4_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_6adab_row4_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_6adab_row4_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_6adab_row4_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_6adab_row4_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_6adab_row4_col7, #T_6adab_row7_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_6adab_row4_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_6adab_row5_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_6adab_row5_col2, #T_6adab_row5_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_6adab_row5_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_6adab_row5_col6, #T_6adab_row8_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_6adab_row5_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_6adab_row5_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_6adab_row6_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_6adab_row6_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_6adab_row6_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_6adab_row6_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_6adab_row6_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_6adab_row7_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_6adab_row7_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_6adab_row7_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_6adab_row7_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_6adab_row8_col0, #T_6adab_row8_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_6adab_row8_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_6adab_row8_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_6adab_row8_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_6adab_row8_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_6adab_row8_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# </style>
# <table id="T_6adab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6adab_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_6adab_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_6adab_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_6adab_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_6adab_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_6adab_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_6adab_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_6adab_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_6adab_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6adab_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_6adab_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_6adab_row0_col1" class="data row0 col1" >0.13</td>
#       <td id="T_6adab_row0_col2" class="data row0 col2" >0.14</td>
#       <td id="T_6adab_row0_col3" class="data row0 col3" >-0.08</td>
#       <td id="T_6adab_row0_col4" class="data row0 col4" >-0.07</td>
#       <td id="T_6adab_row0_col5" class="data row0 col5" >0.02</td>
#       <td id="T_6adab_row0_col6" class="data row0 col6" >-0.03</td>
#       <td id="T_6adab_row0_col7" class="data row0 col7" >0.54</td>
#       <td id="T_6adab_row0_col8" class="data row0 col8" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_6adab_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_6adab_row1_col0" class="data row1 col0" >0.13</td>
#       <td id="T_6adab_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_6adab_row1_col2" class="data row1 col2" >0.15</td>
#       <td id="T_6adab_row1_col3" class="data row1 col3" >0.06</td>
#       <td id="T_6adab_row1_col4" class="data row1 col4" >0.33</td>
#       <td id="T_6adab_row1_col5" class="data row1 col5" >0.22</td>
#       <td id="T_6adab_row1_col6" class="data row1 col6" >0.14</td>
#       <td id="T_6adab_row1_col7" class="data row1 col7" >0.26</td>
#       <td id="T_6adab_row1_col8" class="data row1 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_6adab_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_6adab_row2_col0" class="data row2 col0" >0.14</td>
#       <td id="T_6adab_row2_col1" class="data row2 col1" >0.15</td>
#       <td id="T_6adab_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_6adab_row2_col3" class="data row2 col3" >0.21</td>
#       <td id="T_6adab_row2_col4" class="data row2 col4" >0.09</td>
#       <td id="T_6adab_row2_col5" class="data row2 col5" >0.28</td>
#       <td id="T_6adab_row2_col6" class="data row2 col6" >0.04</td>
#       <td id="T_6adab_row2_col7" class="data row2 col7" >0.24</td>
#       <td id="T_6adab_row2_col8" class="data row2 col8" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_6adab_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_6adab_row3_col0" class="data row3 col0" >-0.08</td>
#       <td id="T_6adab_row3_col1" class="data row3 col1" >0.06</td>
#       <td id="T_6adab_row3_col2" class="data row3 col2" >0.21</td>
#       <td id="T_6adab_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_6adab_row3_col4" class="data row3 col4" >0.44</td>
#       <td id="T_6adab_row3_col5" class="data row3 col5" >0.39</td>
#       <td id="T_6adab_row3_col6" class="data row3 col6" >0.18</td>
#       <td id="T_6adab_row3_col7" class="data row3 col7" >-0.11</td>
#       <td id="T_6adab_

# %%
# 2. 説明変数をX，目的変数をyに分ける
X = dataset.data
y = dataset.target.astype("int")  # 目的変数は整数型に変換

# こっちの方が汎用性が高いです．PandasのDataFrameから変換する方法
df = dataset.frame
X = df.drop(columns=["Outcome"])  # Outcome列を除外
y = df["Outcome"].astype(int)  # Outcome列を抽出 & 整数型に変換

# %%
# 3. 訓練データとテストデータに分割
from sklearn.model_selection import train_test_split  # データ分割用
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=500)  # 80%訓練，20%テスト

# %%
# 4. SVCを使って学習
model = SVC(kernel="linear", C=1.0)  # 線形カーネル，C=1.0
model.fit(X_train, y_train)  # 学習
# Out:
# SVC(kernel='linear')

# %%
# 5. テストデータで予測
y_pred = model.predict(X_test)  # 予測
# 6. 精度を評価
from sklearn.metrics import accuracy_score  # 精度評価用
accuracy = accuracy_score(y_test, y_pred)  # 精度計算
print(f"Accuracy: {accuracy:.3f}")  # 精度を表示(小数点以下3桁)
# Out:
# Accuracy: 0.792

# %%
# 7. 混同行列を表示
from sklearn.metrics import confusion_matrix  # 混同行列用
cm = confusion_matrix(y_test, y_pred)  # 混同行列を計算
plt.matshow(cm, cmap="Blues")  # 混同行列をヒートマップで表示
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(x=j, y=i, s=cm[i, j])

# %%
# おまけ

# ipywidgetで dataset.feature_namesの8変数をスライダーで指定して，その変数の値を使って予測する
# 8. ipywidgetでスライダーを作成
from ipywidgets import interact, FloatSlider  # スライダー作成用
import numpy as np  # 数値計算用

# スライダーの範囲を指定
def create_slider(name, min_value, max_value):
    return FloatSlider(value=(min_value + max_value) / 2, min=min_value, max=max_value, step=0.1, description=name)

# スライダーの値を使って予測する関数
def predict_with_sliders(**kwargs):
    # スライダーの値を使って予測
    input_data = pd.DataFrame({name: [kwargs[name]] for name in dataset.feature_names})
    prediction = model.decision_function(input_data)  # 決定関数を計算
    # 決定関数をlikelihoodに変換
    prediction = 1 / (1 + np.exp(-prediction))  # ロジスティック関数を適用
    print(f"Prediction: {prediction[0]:.2f}")  # 予測結果を表示

# スライダーを作成
sliders = {name: create_slider(name, X[name].min(), X[name].max()) for name in dataset.feature_names}  # スライダーを作成

# スライダーを表示
interact(predict_with_sliders, **sliders)  # スライダーを表示
# Out:
# interactive(children=(FloatSlider(value=8.5, description='Pregnancies', max=17.0), FloatSlider(value=99.5, des…
# <function __main__.predict_with_sliders(**kwargs)>
